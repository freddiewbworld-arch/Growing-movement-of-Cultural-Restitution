# %%
# !pip install -U crawl4ai
# !pip install nest_asyncio
# Out:
# Collecting crawl4ai
#   Downloading crawl4ai-0.8.6-py3-none-any.whl.metadata (55 kB)
# Collecting aiofiles>=24.1.0 (from crawl4ai)
#   Downloading aiofiles-25.1.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: aiohttp>=3.11.11 in /opt/anaconda3/lib/python3.13/site-packages (from crawl4ai) (3.13.2)
# Collecting aiosqlite~=0.20 (from crawl4ai)
#   Downloading aiosqlite-0.22.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: anyio>=4.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from crawl4ai) (4.10.0)
# Requirement already satisfied: lxml~=5.3 in /opt/anaconda3/lib/python3.13/site-packages (from crawl4ai) (5.3.0)
# Collecting unclecode-litellm==1.81.13 (from crawl4ai)
#   Downloading unclecode_litellm-1.81.13-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: numpy<3,>=1.26.0 in /opt/anaconda3/lib/python3.13/site-packages (from crawl4ai) (2.3.5)
# Requirement already satisfied: pillow>=10.4 in /opt/anaconda3/lib/python3.13/site-packages (from crawl4ai) (12.0.0)
# Collecting playwright>=1.49.0 (from crawl4ai)
#   Downloading playwright-1.59.0-py3-none-macosx_11_0_arm64.whl.metadata (3.5 kB)
# Collecting patchright>=1.49.0 (from crawl4ai)
#   Downloading patchright-1.59.1-py3-none-macosx_11_0_arm64.whl.metadata (13 kB)
# Requirement already satisfied: python-dotenv~=1.0 in /opt/anaconda3/lib/python3.13/site-packages (from crawl4ai) (1.1.0)
# Requirement already satisfied: requests~=2.26 in /opt/anaconda3/lib/python3.13/site-packages (from crawl4ai) (2.32.5)
# Requirement already satisfied: beautifulsoup4~=4.12 in /opt/anaconda3/lib/python3.13/site-packages (from crawl4ai) (4.13.5)
# Collecting playwright-stealth>=2.0.0 (from crawl4ai)
#   Downloading playwright_stealth-2.0.3-py3-none-any.whl.metadata (4.5 kB)
# Collecting xxhash~=3.4 (from crawl4ai)
#   Downloading xxhash-3.7.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (13 kB)
# Collecting rank-bm25~=0.2 (from crawl4ai)
#   Downloading rank_bm25-0.2.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting snowballstemmer~=2.2 (from crawl4ai)
#   Downloading snowballstemmer-2.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: pydantic>=2.10 in /opt/anaconda3/lib/python3.13/site-packages (from crawl4ai) (2.12.4)
# Requirement already satisfied: pyOpenSSL>=25.3.0 in /opt/anaconda3/lib/python3.13/site-packages (from crawl4ai) (25.3.0)
# Requirement already satisfied: psutil>=6.1.1 in /opt/anaconda3/lib/python3.13/site-packages (from crawl4ai) (7.0.0)
# Requirement already satisfied: PyYAML>=6.0 in /opt/anaconda3/lib/python3.13/site-packages (from crawl4ai) (6.0.3)
# Requirement already satisfied: nltk>=3.9.1 in /opt/anaconda3/lib/python3.13/site-packages (from crawl4ai) (3.9.2)
# Requirement already satisfied: rich>=13.9.4 in /opt/anaconda3/lib/python3.13/site-packages (from crawl4ai) (14.2.0)
# Requirement already satisfied: cssselect>=1.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from crawl4ai) (1.2.0)
# Requirement already satisfied: httpx>=0.27.2 in /opt/anaconda3/lib/python3.13/site-packages (from crawl4ai) (0.28.1)
# Collecting fake-useragent>=2.0.3 (from crawl4ai)
#   Downloading fake_useragent-2.2.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: click>=8.1.7 in /opt/anaconda3/lib/python3.13/site-packages (from crawl4ai) (8.2.1)
# Requirement already satisfied: chardet>=5.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from crawl4ai) (5.2.0)
# Collecting brotli>=1.1.0 (from crawl4ai)
#   Downloading brotli-1.2.0-cp313-cp313-macosx_10_13_universal2.whl.metadata (6.1 kB)
# Collecting humanize>=4.10.0 (from crawl4ai)
#   Downloading humanize-4.15.0-py3-none-any.whl.metadata (7.8 kB)
# Collecting lark>=1.2.2 (from crawl4ai)
#   Downloading lark-1.3.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting alphashape>=1.3.1 (from crawl4ai)
#   Downloading alphashape-1.3.1-py2.py3-none-any.whl.metadata (18 kB)
# Collecting shapely>=2.0.0 (from crawl4ai)
#   Downloading shapely-2.1.2-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting fastuuid>=0.13.0 (from unclecode-litellm==1.81.13->crawl4ai)
#   Downloading fastuuid-0.14.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (1.1 kB)
# Collecting openai>=2.8.0 (from unclecode-litellm==1.81.13->crawl4ai)
#   Downloading openai-2.36.0-py3-none-any.whl.metadata (31 kB)
# Collecting tiktoken>=0.7.0 (from unclecode-litellm==1.81.13->crawl4ai)
#   Downloading tiktoken-0.12.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /opt/anaconda3/lib/python3.13/site-packages (from unclecode-litellm==1.81.13->crawl4ai) (8.7.0)
# Requirement already satisfied: tokenizers in /opt/anaconda3/lib/python3.13/site-packages (from unclecode-litellm==1.81.13->crawl4ai) (0.22.2)
# Requirement already satisfied: jinja2>=3.1.2 in /opt/anaconda3/lib/python3.13/site-packages (from unclecode-litellm==1.81.13->crawl4ai) (3.1.6)
# Requirement already satisfied: jsonschema<5.0.0,>=4.23.0 in /opt/anaconda3/lib/python3.13/site-packages (from unclecode-litellm==1.81.13->crawl4ai) (4.25.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.13/site-packages (from beautifulsoup4~=4.12->crawl4ai) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from beautifulsoup4~=4.12->crawl4ai) (4.15.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from jsonschema<5.0.0,>=4.23.0->unclecode-litellm==1.81.13->crawl4ai) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/lib/python3.13/site-packages (from jsonschema<5.0.0,>=4.23.0->unclecode-litellm==1.81.13->crawl4ai) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/lib/python3.13/site-packages (from jsonschema<5.0.0,>=4.23.0->unclecode-litellm==1.81.13->crawl4ai) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/lib/python3.13/site-packages (from jsonschema<5.0.0,>=4.23.0->unclecode-litellm==1.81.13->crawl4ai) (0.28.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/lib/python3.13/site-packages (from requests~=2.26->crawl4ai) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.13/site-packages (from requests~=2.26->crawl4ai) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.13/site-packages (from requests~=2.26->crawl4ai) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.13/site-packages (from requests~=2.26->crawl4ai) (2026.1.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp>=3.11.11->crawl4ai) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp>=3.11.11->crawl4ai) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp>=3.11.11->crawl4ai) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp>=3.11.11->crawl4ai) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp>=3.11.11->crawl4ai) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp>=3.11.11->crawl4ai) (1.22.0)
# Collecting click-log>=0.3.2 (from alphashape>=1.3.1->crawl4ai)
#   Downloading click_log-0.4.0-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting trimesh>=3.9.8 (from alphashape>=1.3.1->crawl4ai)
#   Downloading trimesh-4.12.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: networkx>=2.5 in /opt/anaconda3/lib/python3.13/site-packages (from alphashape>=1.3.1->crawl4ai) (3.5)
# Requirement already satisfied: rtree>=0.9.7 in /opt/anaconda3/lib/python3.13/site-packages (from alphashape>=1.3.1->crawl4ai) (1.4.1)
# Requirement already satisfied: scipy>=1.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from alphashape>=1.3.1->crawl4ai) (1.16.3)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/lib/python3.13/site-packages (from anyio>=4.0.0->crawl4ai) (1.3.0)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.13/site-packages (from httpx>=0.27.2->crawl4ai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.27.2->crawl4ai) (0.16.0)
# Collecting h2<5,>=3 (from httpx[http2]>=0.27.2->crawl4ai)
#   Downloading h2-4.3.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting hyperframe<7,>=6.1 (from h2<5,>=3->httpx[http2]>=0.27.2->crawl4ai)
#   Downloading hyperframe-6.1.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting hpack<5,>=4.1 (from h2<5,>=3->httpx[http2]>=0.27.2->crawl4ai)
#   Downloading hpack-4.1.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: zipp>=3.20 in /opt/anaconda3/lib/python3.13/site-packages (from importlib-metadata>=6.8.0->unclecode-litellm==1.81.13->crawl4ai) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.13/site-packages (from jinja2>=3.1.2->unclecode-litellm==1.81.13->crawl4ai) (3.0.2)
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.13/site-packages (from nltk>=3.9.1->crawl4ai) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/anaconda3/lib/python3.13/site-packages (from nltk>=3.9.1->crawl4ai) (2025.9.1)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.13/site-packages (from nltk>=3.9.1->crawl4ai) (4.67.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/anaconda3/lib/python3.13/site-packages (from openai>=2.8.0->unclecode-litellm==1.81.13->crawl4ai) (1.9.0)
# Collecting jiter<1,>=0.10.0 (from openai>=2.8.0->unclecode-litellm==1.81.13->crawl4ai)
#   Downloading jiter-0.14.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic>=2.10->crawl4ai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic>=2.10->crawl4ai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic>=2.10->crawl4ai) (0.4.2)
# Collecting pyee<14,>=13 (from patchright>=1.49.0->crawl4ai)
#   Downloading pyee-13.0.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: greenlet<4.0.0,>=3.1.1 in /opt/anaconda3/lib/python3.13/site-packages (from patchright>=1.49.0->crawl4ai) (3.2.4)
# Requirement already satisfied: cryptography<47,>=45.0.7 in /opt/anaconda3/lib/python3.13/site-packages (from pyOpenSSL>=25.3.0->crawl4ai) (46.0.3)
# Requirement already satisfied: cffi>=2.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from cryptography<47,>=45.0.7->pyOpenSSL>=25.3.0->crawl4ai) (2.0.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.13/site-packages (from cffi>=2.0.0->cryptography<47,>=45.0.7->pyOpenSSL>=25.3.0->crawl4ai) (2.23)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from rich>=13.9.4->crawl4ai) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.13/site-packages (from rich>=13.9.4->crawl4ai) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->crawl4ai) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /opt/anaconda3/lib/python3.13/site-packages (from tokenizers->unclecode-litellm==1.81.13->crawl4ai) (1.4.1)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->unclecode-litellm==1.81.13->crawl4ai) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->unclecode-litellm==1.81.13->crawl4ai) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->unclecode-litellm==1.81.13->crawl4ai) (1.3.1)
# Requirement already satisfied: packaging>=20.9 in /opt/anaconda3/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->unclecode-litellm==1.81.13->crawl4ai) (25.0)
# Requirement already satisfied: shellingham in /opt/anaconda3/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->unclecode-litellm==1.81.13->crawl4ai) (1.5.4)
# Requirement already satisfied: typer-slim in /opt/anaconda3/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->unclecode-litellm==1.81.13->crawl4ai) (0.24.0)
# Requirement already satisfied: typer>=0.24.0 in /opt/anaconda3/lib/python3.13/site-packages (from typer-slim->huggingface-hub<2.0,>=0.16.4->tokenizers->unclecode-litellm==1.81.13->crawl4ai) (0.24.1)
# Requirement already satisfied: annotated-doc>=0.0.2 in /opt/anaconda3/lib/python3.13/site-packages (from typer>=0.24.0->typer-slim->huggingface-hub<2.0,>=0.16.4->tokenizers->unclecode-litellm==1.81.13->crawl4ai) (0.0.4)
# Downloading crawl4ai-0.8.6-py3-none-any.whl (501 kB)
# Downloading unclecode_litellm-1.81.13-py3-none-any.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 5.6 MB/s  0:00:035.5 MB/s eta 0:00:01:01
# Downloading aiosqlite-0.22.1-py3-none-any.whl (17 kB)
# Downloading rank_bm25-0.2.2-py3-none-any.whl (8.6 kB)
# Downloading snowballstemmer-2.2.0-py2.py3-none-any.whl (93 kB)
# Downloading xxhash-3.7.0-cp313-cp313-macosx_11_0_arm64.whl (30 kB)
# Downloading aiofiles-25.1.0-py3-none-any.whl (14 kB)
# Downloading alphashape-1.3.1-py2.py3-none-any.whl (13 kB)
# Downloading brotli-1.2.0-cp313-cp313-macosx_10_13_universal2.whl (861 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 861.5/861.5 kB 11.6 MB/s  0:00:00
# Downloading click_log-0.4.0-py2.py3-none-any.whl (4.3 kB)
# Downloading fake_useragent-2.2.0-py3-none-any.whl (161 kB)
# Downloading fastuuid-0.14.0-cp313-cp313-macosx_11_0_arm64.whl (251 kB)
# Downloading h2-4.3.0-py3-none-any.whl (61 kB)
# Downloading hpack-4.1.0-py3-none-any.whl (34 kB)
# Downloading hyperframe-6.1.0-py3-none-any.whl (13 kB)
# Downloading humanize-4.15.0-py3-none-any.whl (132 kB)
# Downloading lark-1.3.1-py3-none-any.whl (113 kB)
# Downloading openai-2.36.0-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 6.2 MB/s  0:00:007.3 MB/s eta 0:00:01
# Downloading jiter-0.14.0-cp313-cp313-macosx_11_0_arm64.whl (314 kB)
# Downloading patchright-1.59.1-py3-none-macosx_11_0_arm64.whl (41.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 MB 2.9 MB/s  0:00:14 eta 0:00:010:00:01
# Downloading pyee-13.0.1-py3-none-any.whl (15 kB)
# Downloading playwright-1.59.0-py3-none-macosx_11_0_arm64.whl (41.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 MB 2.3 MB/s  0:00:18 eta 0:00:010:00:01
# Downloading playwright_stealth-2.0.3-py3-none-any.whl (34 kB)
# Downloading shapely-2.1.2-cp313-cp313-macosx_11_0_arm64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 3.5 MB/s  0:00:00m 3.5 MB/s eta 0:00:01
# Downloading tiktoken-0.12.0-cp313-cp313-macosx_11_0_arm64.whl (993 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 994.0/994.0 kB 2.4 MB/s  0:00:002.2 MB/s eta 0:00:01
# Downloading trimesh-4.12.2-py3-none-any.whl (741 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 741.0/741.0 kB 2.8 MB/s  0:00:00? eta -:--:--
# Installing collected packages: snowballstemmer, brotli, xxhash, trimesh, shapely, rank-bm25, pyee, lark, jiter, hyperframe, humanize, hpack, fastuuid, fake-useragent, click-log, aiosqlite, aiofiles, tiktoken, playwright, patchright, h2, alphashape, playwright-stealth, openai, unclecode-litellm, crawl4ai
#   Attempting uninstall: snowballstemmer
#     Found existing installation: snowballstemmer 3.0.1
#     Uninstalling snowballstemmer-3.0.1:
#       Successfully uninstalled snowballstemmer-3.0.1
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26/26 [crawl4ai]237m━━━ 24/26 [unclecode-litellm]
# Successfully installed aiofiles-25.1.0 aiosqlite-0.22.1 alphashape-1.3.1 brotli-1.2.0 click-log-0.4.0 crawl4ai-0.8.6 fake-useragent-2.2.0 fastuuid-0.14.0 h2-4.3.0 hpack-4.1.0 humanize-4.15.0 hyperframe-6.1.0 jiter-0.14.0 lark-1.3.1 openai-2.36.0 patchright-1.59.1 playwright-1.59.0 playwright-stealth-2.0.3 pyee-13.0.1 rank-bm25-0.2.2 shapely-2.1.2 snowballstemmer-2.2.0 tiktoken-0.12.0 trimesh-4.12.2 unclecode-litellm-1.81.13 xxhash-3.7.0
# Requirement already satisfied: nest_asyncio in /opt/anaconda3/lib/python3.13/site-packages (1.6.0)

# %%
# !crawl4ai-setup
# Out:
# [INIT].... → Running post-installation setup...
# [INIT].... → Installing Playwright browsers...
# Downloading Chrome for Testing 147.0.7727.15 (playwright chromium v1217) from https://cdn.playwright.dev/builds/cft/147.0.7727.15/mac-arm64/chrome-mac-arm64.zip
# 165.5 MiB [                    ] 0% 0.0s165.5 MiB [                    ] 0% 242.4s165.5 MiB [                    ] 0% 258.0s165.5 MiB [                    ] 0% 288.6s165.5 MiB [                    ] 0% 217.7s165.5 MiB [                    ] 0% 321.3s165.5 MiB [                    ] 0% 261.2s165.5 MiB [                    ] 0% 260.4s165.5 MiB [                    ] 0% 189.3s165.5 MiB [                    ] 0% 196.0s165.5 MiB [                    ] 0% 191.4s165.5 MiB [                    ] 0% 167.3s165.5 MiB [                    ] 0% 159.7s165.5 MiB [                    ] 0% 152.8s165.5 MiB [                    ] 0% 142.4s165.5 MiB [                    ] 0% 142.1s165.5 MiB [                    ] 0% 135.7s165.5 MiB [                    ] 0% 133.2s165.5 MiB [                    ] 0% 124.7s165.5 MiB [                    ] 0% 122.7s165.5 MiB [                    ] 0% 117.4s165.5 MiB [                    ] 0% 118.5s165.5 MiB [                    ] 0% 120.0s165.5 MiB [                    ] 0% 115.5s165.5 MiB [                    ] 0% 115.0s165.5 MiB [                    ] 0% 111.7s165.5 MiB [                    ] 0% 113.4s165.5 MiB [                    ] 0% 115.1s165.5 MiB [                    ] 0% 112.1s165.5 MiB [                    ] 0% 110.5s165.5 MiB [                    ] 0% 110.2s165.5 MiB [                    ] 0% 107.1s165.5 MiB [                    ] 0% 106.8s165.5 MiB [                    ] 0% 107.3s165.5 MiB [                    ] 0% 106.2s165.5 MiB [                    ] 0% 105.7s165.5 MiB [                    ] 0% 100.7s165.5 MiB [                    ] 0% 103.6s165.5 MiB [                    ] 0% 103.1s165.5 MiB [                    ] 0% 103.2s165.5 MiB [                    ] 0% 101.2s165.5 MiB [                    ] 0% 101.5s165.5 MiB [                    ] 0% 99.7s165.5 MiB [                    ] 0% 99.6s165.5 MiB [                    ] 0% 99.8s165.5 MiB [                    ] 0% 99.0s165.5 MiB [                    ] 0% 99.7s165.5 MiB [                    ] 0% 98.4s165.5 MiB [                    ] 0% 97.6s165.5 MiB [                    ] 1% 96.3s165.5 MiB [                    ] 1% 95.4s165.5 MiB [                    ] 1% 94.3s165.5 MiB [                    ] 1% 94.7s165.5 MiB [                    ] 1% 95.6s165.5 MiB [                    ] 1% 93.1s165.5 MiB [                    ] 1% 94.1s165.5 MiB [                    ] 1% 93.9s165.5 MiB [                    ] 1% 93.2s165.5 MiB [                    ] 1% 93.0s165.5 MiB [                    ] 1% 92.9s165.5 MiB [                    ] 1% 92.5s165.5 MiB [                    ] 1% 93.6s165.5 MiB [                    ] 1% 92.8s165.5 MiB [                    ] 1% 92.2s165.5 MiB [                    ] 1% 92.7s165.5 MiB [                    ] 1% 91.4s165.5 MiB [                    ] 1% 90.4s165.5 MiB [                    ] 1% 89.9s165.5 MiB [                    ] 1% 89.8s165.5 MiB [                    ] 1% 90.6s165.5 MiB [                    ] 1% 90.2s165.5 MiB [                    ] 1% 89.2s165.5 MiB [                    ] 1% 89.7s165.5 MiB [                    ] 1% 89.5s165.5 MiB [                    ] 1% 88.5s165.5 MiB [                    ] 1% 88.7s165.5 MiB [                    ] 1% 88.1s165.5 MiB [                    ] 1% 87.7s165.5 MiB [                    ] 1% 87.6s165.5 MiB [                    ] 1% 86.7s165.5 MiB [                    ] 1% 86.3s165.5 MiB [                    ] 1% 86.2s165.5 MiB [                    ] 1% 86.4s165.5 MiB [                    ] 1% 85.6s165.5 MiB [                    ] 2% 85.4s165.5 MiB [                    ] 2% 85.5s165.5 MiB [                    ] 2% 85.2s165.5 MiB [                    ] 2% 84.6s165.5 MiB [                    ] 2% 84.3s165.5 MiB [                    ] 2% 83.7s165.5 MiB [                    ] 2% 83.5s165.5 MiB [                    ] 2% 83.6s165.5 MiB [                    ] 2% 83.7s165.5 MiB [                    ] 2% 83.6s165.5 MiB [                    ] 2% 83.3s165.5 MiB [                    ] 2% 83.1s165.5 MiB [              ...
# Chrome for Testing 147.0.7727.15 (playwright chromium v1217) downloaded to /Users/freddie/Library/Caches/ms-playwright/chromium-1217
# Downloading FFmpeg (playwright ffmpeg v1011) from https://cdn.playwright.dev/dbazure/download/playwright/builds/ffmpeg/1011/ffmpeg-mac-arm64.zip
# 1 MiB [                    ] 0% 0.0s1 MiB [=                   ] 3% 0.5s1 MiB [=                   ] 4% 0.8s1 MiB [==                  ] 11% 0.4s1 MiB [====                ] 17% 0.3s1 MiB [====                ] 20% 0.4s1 MiB [====                ] 22% 0.4s1 MiB [========            ] 40% 0.2s1 MiB [==========          ] 47% 0.2s1 MiB [===========         ] 56% 0.1s1 MiB [=============       ] 63% 0.1s1 MiB [================    ] 78% 0.1s1 MiB [==================  ] 92% 0.0s1 MiB [=================== ] 97% 0.0s1 MiB [====================] 100% 0.0s
# FFmpeg (playwright ffmpeg v1011) downloaded to /Users/freddie/Library/Caches/ms-playwright/ffmpeg-1011
# Downloading Chrome Headless Shell 147.0.7727.15 (playwright chromium-headless-shell v1217) from https://cdn.playwright.dev/builds/cft/147.0.7727.15/mac-arm64/chrome-headless-shell-mac-arm64.zip
# 92 MiB [                    ] 0% 0.0s92 MiB [                    ] 0% 187.3s92 MiB [                    ] 0% 129.5s92 MiB [                    ] 0% 178.1s92 MiB [                    ] 0% 137.0s92 MiB [                    ] 0% 205.6s92 MiB [                    ] 0% 164.5s92 MiB [                    ] 0% 145.6s92 MiB [                    ] 0% 127.6s92 MiB [                    ] 0% 117.0s92 MiB [                    ] 0% 110.0s92 MiB [                    ] 0% 106.0s92 MiB [                    ] 0% 96.3s92 MiB [                    ] 0% 83.0s92 MiB [                    ] 0% 78.2s92 MiB [                    ] 0% 67.1s92 MiB [                    ] 0% 62.9s92 MiB [                    ] 0% 54.8s92 MiB [                    ] 0% 51.6s92 MiB [                    ] 0% 51.4s92 MiB [                    ] 1% 42.6s92 MiB [                    ] 1% 40.3s92 MiB [                    ] 1% 40.5s92 MiB [                    ] 1% 37.7s92 MiB [                    ] 1% 33.7s92 MiB [                    ] 1% 32.0s92 MiB [                    ] 1% 31.5s92 MiB [                    ] 1% 30.1s92 MiB [                    ] 2% 30.2s92 MiB [                    ] 2% 28.1s92 MiB [                    ] 2% 26.3s92 MiB [=                   ] 2% 26.2s92 MiB [=                   ] 2% 25.9s92 MiB [=                   ] 2% 24.6s92 MiB [=                   ] 3% 23.6s92 MiB [=                   ] 3% 23.5s92 MiB [=                   ] 3% 22.3s92 MiB [=                   ] 3% 21.8s92 MiB [=                   ] 3% 21.9s92 MiB [=                   ] 4% 21.8s92 MiB [=                   ] 4% 23.3s92 MiB [=                   ] 4% 23.1s92 MiB [=                   ] 4% 22.7s92 MiB [=                   ] 4% 22.2s92 MiB [=                   ] 4% 22.0s92 MiB [=                   ] 4% 22.2s92 MiB [=                   ] 4% 22.1s92 MiB [=                   ] 4% 22.0s92 MiB [=                   ] 4% 21.9s92 MiB [=                   ] 5% 21.7s92 MiB [=                   ] 5% 21.0s92 MiB [=                   ] 5% 21.2s92 MiB [=                   ] 5% 20.7s92 MiB [=                   ] 5% 20.6s92 MiB [=                   ] 5% 20.3s92 MiB [=                   ] 5% 20.0s92 MiB [=                   ] 6% 20.0s92 MiB [=                   ] 6% 19.8s92 MiB [=                   ] 6% 19.2s92 MiB [=                   ] 6% 18.8s92 MiB [=                   ] 6% 18.7s92 MiB [=                   ] 6% 18.9s92 MiB [=                   ] 7% 18.8s92 MiB [=                   ] 7% 18.6s92 MiB [=                   ] 7% 18.8s92 MiB [=                   ] 7% 18.7s92 MiB [==                  ] 7% 18.8s92 MiB [==                  ] 7% 18.6s92 MiB [==                  ] 7% 19.5s92 MiB [==                  ] 8% 17.9s92 MiB [==                  ] 8% 18.0s92 MiB [==                  ] 8% 17.6s92 MiB [==                  ] 9% 17.7s92 MiB [==                  ] 9% 17.8s92 MiB [==                  ] 9% 17.6s92 MiB [==                  ] 9% 17.5s92 MiB [==                  ] 9% 17.6s92 MiB [==                  ] 10% 17.5s92 MiB [==                  ] 10% 17.3s92 MiB [==                  ] 10% 17.2s92 MiB [==                  ] 10% 17.4s92 MiB [==                  ] 10% 17.3s92 MiB [==                  ] 10% 17.2s92 MiB [==                  ] 10% 17.1s92 MiB [==                  ] 10% 17.2s92 MiB [==                  ] 11% 17.1s92 MiB [==                  ] 11% 17.4s92 MiB [==                  ] 11% 17.3s92 MiB [==                  ] 11% 17.4s92 MiB [==                  ] 11% 17.5s92 MiB [==                  ] 11% 17.4s92 MiB [==                  ] 11% 17.3s92 MiB [==                  ] 11% 17.2s92 MiB [==                  ] 12% 17.1s92 MiB [==                  ] 12% 17.0s92 MiB [==                  ] 12% 17.1s92 MiB [==                  ] 12% 17.2s92 MiB [===                 ] 12% 17.1s92 MiB [===                 ] 12% 17.0s92 MiB [===                 ] 12% 16.9s92 MiB [===                 ] 13% 16.9s92 MiB [===                 ] 13% 16.7s92 MiB [===                 ] 13% 16.6s92 MiB [===                 ] 14% 16.7s92 MiB [=== ...
# Chrome Headless Shell 147.0.7727.15 (playwright chromium-headless-shell v1217) downloaded to /Users/freddie/Library/Caches/ms-playwright/chromium_headless_shell-1217
# [COMPLETE] ● Playwright installation completed successfully.
# [INIT].... → Installing Patchright browsers for undetected mode...
# Downloading Chrome for Testing 147.0.7727.15 (playwright chromium v1217) from https://cdn.playwright.dev/builds/cft/147.0.7727.15/mac-arm64/chrome-mac-arm64.zip
# 165.5 MiB [                    ] 0% 0.0s165.5 MiB [                    ] 0% 389.4s165.5 MiB [                    ] 0% 289.1s165.5 MiB [                    ] 0% 278.4s165.5 MiB [                    ] 0% 330.9s165.5 MiB [                    ] 0% 278.9s165.5 MiB [                    ] 0% 382.6s165.5 MiB [                    ] 0% 295.0s165.5 MiB [                    ] 0% 293.0s165.5 MiB [                    ] 0% 258.0s165.5 MiB [                    ] 0% 221.1s165.5 MiB [                    ] 0% 206.9s165.5 MiB [                    ] 0% 197.2s165.5 MiB [                    ] 0% 183.8s165.5 MiB [                    ] 0% 168.5s165.5 MiB [                    ] 0% 157.8s165.5 MiB [                    ] 0% 135.3s165.5 MiB [                    ] 0% 139.8s165.5 MiB [                    ] 0% 123.6s165.5 MiB [                    ] 0% 106.6s165.5 MiB [                    ] 0% 99.2s165.5 MiB [                    ] 0% 94.6s165.5 MiB [                    ] 0% 89.7s165.5 MiB [                    ] 0% 83.5s165.5 MiB [                    ] 0% 79.0s165.5 MiB [                    ] 0% 68.8s165.5 MiB [                    ] 0% 70.5s165.5 MiB [                    ] 0% 64.9s165.5 MiB [                    ] 0% 61.5s165.5 MiB [                    ] 1% 59.8s165.5 MiB [                    ] 1% 54.8s165.5 MiB [                    ] 1% 54.9s165.5 MiB [                    ] 1% 53.9s165.5 MiB [                    ] 1% 52.1s165.5 MiB [                    ] 1% 50.1s165.5 MiB [                    ] 1% 47.8s165.5 MiB [                    ] 1% 45.0s165.5 MiB [                    ] 1% 45.3s165.5 MiB [                    ] 1% 43.8s165.5 MiB [                    ] 1% 41.8s165.5 MiB [                    ] 2% 41.1s165.5 MiB [                    ] 2% 40.5s165.5 MiB [                    ] 2% 38.9s165.5 MiB [                    ] 2% 38.0s165.5 MiB [                    ] 2% 37.9s165.5 MiB [=                   ] 2% 36.6s165.5 MiB [=                   ] 2% 36.2s165.5 MiB [=                   ] 2% 35.9s165.5 MiB [=                   ] 2% 36.2s165.5 MiB [=                   ] 2% 34.9s165.5 MiB [=                   ] 2% 35.1s165.5 MiB [=                   ] 3% 35.2s165.5 MiB [=                   ] 3% 35.5s165.5 MiB [=                   ] 3% 35.4s165.5 MiB [=                   ] 3% 34.7s165.5 MiB [=                   ] 3% 34.1s165.5 MiB [=                   ] 3% 33.8s165.5 MiB [=                   ] 3% 33.6s165.5 MiB [=                   ] 3% 33.5s165.5 MiB [=                   ] 3% 32.7s165.5 MiB [=                   ] 3% 32.5s165.5 MiB [=                   ] 4% 31.6s165.5 MiB [=                   ] 4% 31.4s165.5 MiB [=                   ] 4% 31.1s165.5 MiB [=                   ] 4% 31.3s165.5 MiB [=                   ] 4% 31.0s165.5 MiB [=                   ] 4% 30.5s165.5 MiB [=                   ] 4% 30.9s165.5 MiB [=                   ] 4% 30.4s165.5 MiB [=                   ] 4% 30.9s165.5 MiB [=                   ] 4% 31.0s165.5 MiB [=                   ] 4% 30.7s165.5 MiB [=                   ] 5% 30.3s165.5 MiB [=                   ] 5% 30.6s165.5 MiB [=                   ] 5% 30.4s165.5 MiB [=                   ] 5% 30.5s165.5 MiB [=                   ] 5% 30.7s165.5 MiB [=                   ] 5% 33.4s165.5 MiB [=                   ] 5% 30.6s165.5 MiB [=                   ] 5% 30.9s165.5 MiB [=                   ] 5% 31.0s165.5 MiB [=                   ] 5% 31.1s165.5 MiB [=                   ] 6% 30.8s165.5 MiB [=                   ] 6% 30.6s165.5 MiB [=                   ] 6% 30.9s165.5 MiB [=                   ] 6% 30.8s165.5 MiB [=                   ] 6% 31.0s165.5 MiB [=                   ] 6% 30.7s165.5 MiB [=                   ] 6% 30.6s165.5 MiB [=                   ] 6% 30.8s165.5 MiB [=                   ] 6% 30.4s165.5 MiB [=                   ] 6% 30.5s165.5 MiB [=                   ] 6% 30.4s165.5 MiB [=                   ] 6% 30.2s165.5 MiB [=                   ] 6% 30.4s165.5 MiB [=                   ] 6% 30.2s165.5 MiB [=                   ] 7% 30.2s165.5 ...
# Chrome for Testing 147.0.7727.15 (playwright chromium v1217) downloaded to /Users/freddie/Library/Caches/ms-playwright/chromium-1217
# Downloading FFmpeg (playwright ffmpeg v1011) from https://cdn.playwright.dev/dbazure/download/playwright/builds/ffmpeg/1011/ffmpeg-mac-arm64.zip
# 1 MiB [                    ] 0% 0.0s1 MiB [=                   ] 3% 0.8s1 MiB [==                  ] 10% 0.4s1 MiB [==                  ] 11% 0.5s1 MiB [===                 ] 16% 0.4s1 MiB [====                ] 22% 0.3s1 MiB [======              ] 28% 0.3s1 MiB [=======             ] 32% 0.3s1 MiB [=======             ] 37% 0.3s1 MiB [=========           ] 44% 0.2s1 MiB [==========          ] 52% 0.2s1 MiB [=============       ] 62% 0.1s1 MiB [=============       ] 66% 0.1s1 MiB [===============     ] 74% 0.1s1 MiB [================    ] 78% 0.1s1 MiB [=================   ] 83% 0.1s1 MiB [==================  ] 89% 0.0s1 MiB [=================== ] 97% 0.0s1 MiB [====================] 100% 0.0s
# FFmpeg (playwright ffmpeg v1011) downloaded to /Users/freddie/Library/Caches/ms-playwright/ffmpeg-1011
# Downloading Chrome Headless Shell 147.0.7727.15 (playwright chromium-headless-shell v1217) from https://cdn.playwright.dev/builds/cft/147.0.7727.15/mac-arm64/chrome-headless-shell-mac-arm64.zip
# 92 MiB [                    ] 0% 0.0s92 MiB [                    ] 0% 159.3s92 MiB [                    ] 0% 181.3s92 MiB [                    ] 0% 188.5s92 MiB [                    ] 0% 174.2s92 MiB [                    ] 0% 206.1s92 MiB [                    ] 0% 203.3s92 MiB [                    ] 0% 166.4s92 MiB [                    ] 0% 183.7s92 MiB [                    ] 0% 136.9s92 MiB [                    ] 0% 139.0s92 MiB [                    ] 0% 121.4s92 MiB [                    ] 0% 112.7s92 MiB [                    ] 0% 101.0s92 MiB [                    ] 0% 88.4s92 MiB [                    ] 0% 79.4s92 MiB [                    ] 0% 83.2s92 MiB [                    ] 0% 72.8s92 MiB [                    ] 0% 80.9s92 MiB [                    ] 0% 80.0s92 MiB [                    ] 0% 75.2s92 MiB [                    ] 0% 77.6s92 MiB [                    ] 0% 78.4s92 MiB [                    ] 0% 79.1s92 MiB [                    ] 0% 67.5s92 MiB [                    ] 1% 66.6s92 MiB [                    ] 1% 66.3s92 MiB [                    ] 1% 62.7s92 MiB [                    ] 1% 59.1s92 MiB [                    ] 1% 56.2s92 MiB [                    ] 1% 56.6s92 MiB [                    ] 1% 56.3s92 MiB [                    ] 1% 55.8s92 MiB [                    ] 1% 54.2s92 MiB [                    ] 1% 53.6s92 MiB [                    ] 1% 51.6s92 MiB [                    ] 1% 46.9s92 MiB [                    ] 2% 46.9s92 MiB [                    ] 2% 45.8s92 MiB [                    ] 2% 47.6s92 MiB [                    ] 2% 46.9s92 MiB [                    ] 2% 46.6s92 MiB [                    ] 2% 46.4s92 MiB [                    ] 2% 44.7s92 MiB [=                   ] 2% 44.2s92 MiB [=                   ] 2% 43.4s92 MiB [=                   ] 2% 42.8s92 MiB [=                   ] 2% 42.0s92 MiB [=                   ] 2% 42.5s92 MiB [=                   ] 2% 42.3s92 MiB [=                   ] 3% 41.2s92 MiB [=                   ] 3% 44.4s92 MiB [=                   ] 3% 42.7s92 MiB [=                   ] 3% 47.3s92 MiB [=                   ] 3% 41.3s92 MiB [=                   ] 3% 41.8s92 MiB [=                   ] 3% 42.1s92 MiB [=                   ] 4% 41.7s92 MiB [=                   ] 4% 41.6s92 MiB [=                   ] 4% 45.4s92 MiB [=                   ] 4% 44.6s92 MiB [=                   ] 4% 44.5s92 MiB [=                   ] 5% 41.6s92 MiB [=                   ] 5% 40.4s92 MiB [=                   ] 5% 40.2s92 MiB [=                   ] 5% 40.3s92 MiB [=                   ] 5% 40.1s92 MiB [=                   ] 5% 39.9s92 MiB [=                   ] 5% 40.2s92 MiB [=                   ] 5% 39.7s92 MiB [=                   ] 5% 40.0s92 MiB [=                   ] 6% 39.7s92 MiB [=                   ] 6% 39.8s92 MiB [=                   ] 6% 40.1s92 MiB [=                   ] 6% 40.0s92 MiB [=                   ] 6% 39.9s92 MiB [=                   ] 6% 39.7s92 MiB [=                   ] 6% 39.8s92 MiB [=                   ] 6% 39.9s92 MiB [=                   ] 6% 39.5s92 MiB [=                   ] 6% 40.1s92 MiB [=                   ] 6% 39.3s92 MiB [=                   ] 6% 39.4s92 MiB [=                   ] 6% 39.3s92 MiB [=                   ] 6% 39.1s92 MiB [=                   ] 6% 38.9s92 MiB [=                   ] 7% 38.8s92 MiB [=                   ] 7% 38.7s92 MiB [=                   ] 7% 38.9s92 MiB [=                   ] 7% 38.7s92 MiB [=                   ] 7% 38.6s92 MiB [=                   ] 7% 38.7s92 MiB [=                   ] 7% 38.5s92 MiB [==                  ] 7% 38.4s92 MiB [==                  ] 7% 38.5s92 MiB [==                  ] 7% 38.3s92 MiB [==                  ] 7% 38.4s92 MiB [==                  ] 7% 38.2s92 MiB [==                  ] 7% 38.3s92 MiB [==                  ] 7% 38.2s92 MiB [==                  ] 7% 38.0s92 MiB [==                  ] 8% 37.8s92 MiB [==                  ] 8% 37.6s92 MiB [==                  ] 8% 37.3s92 MiB [==                  ] 8% 37. ...
# Chrome Headless Shell 147.0.7727.15 (playwright chromium-headless-shell v1217) downloaded to /Users/freddie/Library/Caches/ms-playwright/chromium_headless_shell-1217
# [COMPLETE] ● Patchright installation completed successfully.
# [INIT].... → Starting database initialization...
# [COMPLETE] ● Database backup created at:
# /Users/freddie/.crawl4ai/crawl4ai.db.backup_20260508_102549
# [INIT].... → Starting database migration...
# [COMPLETE] ● Migration completed. 0 records processed.
# [COMPLETE] ● Database initialization completed successfully.
# [COMPLETE] ● Post-installation setup completed!

# %%
# !crawl4ai-doctor
# Out:
# [INIT].... → Running Crawl4AI health check...
# [INIT].... → Crawl4AI 0.8.6
# [TEST].... ℹ Testing crawling capabilities...
# [EXPORT].. ℹ Exporting media (PDF/MHTML/screenshot) took 0.19s
# [FETCH]... ↓ https://crawl4ai.com
# | ✓ | ⏱: 3.10s
# [SCRAPE].. ◆ https://crawl4ai.com
# | ✓ | ⏱: 0.01s
# [COMPLETE] ● https://crawl4ai.com
# | ✓ | ⏱: 3.12s
# [COMPLETE] ● ✅ Crawling test passed!

# %%
import asyncio
import nest_asyncio
nest_asyncio.apply()
from crawl4ai import AsyncWebCrawler, CacheMode, BrowserConfig, CrawlerRunConfig, CacheMode
from crawl4ai.markdown_generation_strategy import DefaultMarkdownGenerator                    #Importing necssary modules

async def article_crawl(): #Function for crawling for articles

    cleaned_md = DefaultMarkdownGenerator( #
        content_source="cleaned_html",  
        options={"ignore_links": True}) 
    
    crawler_run_config = CrawlerRunConfig(markdown_generator=cleaned_md, cache_mode=CacheMode.BYPASS)
    async with AsyncWebCrawler() as crawler:
        result = await crawler.arun(
            url='https://www.returningheritage.com/mandalay-regalia-returned-to-myanmar-burma-by-victoria-albert-museum', #Input URL for web scrapping
            config=crawler_run_config
        )

        markdown_content = result.markdown
        
        with open("article32.md", "w", encoding="utf-8") as f: #Writing results of the scrapping into markdown file
            f.write(markdown_content)
            print("File saved successfully.")


asyncio.run(article_crawl()) #Running function
# Out:
# [INIT].... → Crawl4AI 0.8.6
# [FETCH]... ↓ https://www.returningheritage.com/mandalay-regal...urned-to-myanmar-burma-by-victoria-albert-museum  |
# ✓ | ⏱: 1.42s
# [SCRAPE].. ◆ https://www.returningheritage.com/mandalay-regal...urned-to-myanmar-burma-by-victoria-albert-museum  |
# ✓ | ⏱: 0.01s
# [COMPLETE] ● https://www.returningheritage.com/mandalay-regal...urned-to-myanmar-burma-by-victoria-albert-museum  |
# ✓ | ⏱: 1.44s
# File saved successfully.
